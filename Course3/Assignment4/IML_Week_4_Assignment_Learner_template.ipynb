# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasanthGubbala/MS-in-Information-Science-Machine-Learning/blob/dev/Course3/Assignment4/IML_Week_4_Assignment_Learner_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Objective

# %% [markdown]
# This homework sheet will help reviewing the basic concepts associated with classification models. Please review the lectures, suggested readings, and additional resources before getting started on the HW.

# %% [markdown]
# **Some questions in this assignment will require you to conduct independent research beyond the material covered in the recorded content.**

# %% [markdown]
# **Questions**

# %% [markdown]
# This homework is divided into two main parts. First, a conceptual component will review the basic concepts related to classification models. The second part of the homework is mostly intended to be a brief introduction to fitting and analyzing classifiers in `Python`. Several of these questions are modified from James et al. (2021).

# %% [markdown]
# Marks Distribution
#
# | Question      | Marks |
# | ----------- | ----------- |
# | 1a    |    0.25  |
# | 1b    |    0.25   |
# | 1c    |    0.25   |
# | 1d     |   0.25    |
# | 2a     |    0.50  |
# | 2b     |    0.50  |
# | 3     |     1 |
# | 4a    |    1  |
# | 4b    |    1   |
# | 4c    |     0.5  |
# | 4d     |    1   |
# | 4e     |    1  |
# | 4f     |    1   |
# | 4g     |     0.25  |
# | 4h     |     0.25  |
# | 5a    |     1 |
# | 5b    |     1  |
# | 5c    |     1  |
# | 5d     |     1  |
# | 5e     |     1  |
# | 5f     |     1  |

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# ### Q1. Let’s examine the differences between LDA and QDA.

# %% [markdown]
# #### a) If the Bayes decision boundary is linear, do we expect LDA or QDA to perform better on the training set? What about in the test set?

# %% [markdown]
#  Answer:
#
# Provide answer in the markdown cell
#
# If the Bayes decision boundary is linear, we would generally expect LDA to perform better on the training set, and the performance on the test set would depend on the validity of the assumptions. Here's a breakdown:
#
# **Training Set:**
# - LDA assumes a common covariance matrix for all classes and estimates fewer parameters compared to QDA.
# - With a linear Bayes decision boundary, LDA's simplicity might lead to more stable parameter estimation and better performance on the training set.
#
# **Test Set:**
# - If the linear assumption of the Bayes decision boundary holds and the assumption of a common covariance matrix is valid, LDA is likely to generalize well to the test set.
# - QDA, with its flexibility in modeling different covariance matrices, might perform equally well on the test set if the assumption of a common covariance matrix is not crucial for the underlying data distribution.
# - However, if the true decision boundary is genuinely linear, and the assumption holds, LDA is expected to perform better on both the training and test sets.
#
# In summary, if the Bayes decision boundary is linear, LDA is expected to perform better on the training set due to its simplicity. On the test set, the performance depends on how well the assumptions of LDA hold in the true underlying data distribution. If those assumptions are met, LDA might also perform better on the test set.

# %% [markdown]
# #### b) If the Bayes decision boundary is non-linear, do we expect LDA or QDA to perform better on the training set? On the test set?

# %% [markdown]
# Answer:
#
# Provide answer in the markdown cell
#
# If the Bayes decision boundary is non-linear, we generally expect Quadratic Discriminant Analysis (QDA) to perform better than Linear Discriminant Analysis (LDA) on both the training set and the test set. Here's the rationale:
#
# **Training Set:**
# - In the case of a non-linear Bayes decision boundary, the flexibility of QDA to model different covariance matrices for each class allows it to capture more complex relationships in the training data.
# - QDA is not constrained to assume a linear decision boundary, so it has the potential to fit the training data more closely when the true decision boundary is non-linear.
#
# **Test Set:**
# - If the Bayes decision boundary is non-linear and the true data distribution follows this non-linearity, QDA is expected to generalize better to the test set.
# - LDA, with its assumption of a linear decision boundary, may struggle to capture the true underlying pattern in the data when it is non-linear.
#
# In summary, when the Bayes decision boundary is non-linear, QDA's flexibility in allowing for different covariance matrices makes it more suitable for capturing the complexity of the data. Therefore, we would generally expect QDA to outperform LDA both on the training set and the test set in such cases.

# %% [markdown]
# #### c)In general, as the sample size n increases, do we expect the test prediction accuracy of QDA relative to LDA to improve, decline, or be unchanged? Why?

# %% [markdown]
# Answer:
#
# Provide answer in the markdown cell
#
# As the sample size (\(n\)) increases, we generally expect the test prediction accuracy of Quadratic Discriminant Analysis (QDA) relative to Linear Discriminant Analysis (LDA) to improve. Here's the reasoning:
#
# **With Increasing Sample Size:**
#
# 1. **Improved Parameter Estimation:**
#    - Larger sample sizes provide more data for estimating the parameters of the model.
#    - QDA, being more flexible with separate covariance matrices for each class, has more parameters to estimate than LDA.
#    - With a larger sample size, QDA can more accurately estimate these additional parameters, leading to improved model performance.
#
# 2. **Reduced Overfitting Risk:**
#    - Larger sample sizes generally reduce the risk of overfitting.
#    - QDA, with its flexibility, might be more prone to overfitting with smaller sample sizes. However, as the sample size increases, the risk of fitting noise in the data decreases, allowing QDA to capture the underlying complexity more effectively.
#
# 3. **Better Generalization:**
#    - Models often generalize better to new, unseen data with larger sample sizes.
#    - QDA's flexibility might become more advantageous when there is sufficient data to accurately estimate the covariance matrices for each class.
#
# **Overall Expectation:**
#    - The expectation is that, in general, as the sample size increases, the test prediction accuracy of QDA relative to LDA is likely to improve.
#    - The improved parameter estimation, reduced risk of overfitting, and better generalization contribute to this expectation.
#
# In summary, the larger sample size provides QDA with more data to estimate its additional parameters, potentially improving its ability to capture the underlying complexity of the data and leading to better test prediction accuracy compared to LDA.

# %% [markdown]
# #### d)True or False:
# Even if the Bayes decision boundary for a given problem is linear, we will probably achieve a superior test error rate using QDA rather than LDA because QDA is flexible enough to model a linear decision boundary.

# %% [markdown]
# Answer:
#
# Provide answer in the markdown cell
#
# False.
#
# If the Bayes decision boundary for a given problem is linear, and assuming that the true underlying data distribution aligns with the assumptions of Linear Discriminant Analysis (LDA), then using Quadratic Discriminant Analysis (QDA) is not likely to result in a superior test error rate. Here's why:
#
# 1. **Flexibility of QDA:**
#    - QDA is more flexible than LDA as it allows for different covariance matrices for each class and can capture non-linear decision boundaries.
#    - However, if the true decision boundary is linear, the additional flexibility of QDA may not be beneficial and could lead to overfitting.
#
# 2. **Risk of Overfitting:**
#    - QDA, with its increased flexibility, may be more prone to overfitting, especially when the true decision boundary is linear.
#    - Overfitting occurs when a model captures noise in the training data, and this can lead to poor generalization performance on new, unseen data.
#
# 3. **Simplicity of LDA:**
#    - LDA assumes a common covariance matrix for all classes and a linear decision boundary.
#    - If these assumptions hold, LDA may provide a more parsimonious and robust model for a linear decision boundary.
#
# In summary, if the Bayes decision boundary is linear, and the assumptions of LDA are met, LDA is likely to perform as well as or even outperform QDA on the test set. The additional flexibility of QDA may not offer significant advantages in such scenarios and could potentially lead to overfitting.

# %% [markdown]
# ### Q2) In relation to the odds and the Default dataset

# %% [markdown]
# #### a) On average, what fraction of people with an odds of `0.37` of defaulting on their credit card payment will in fact default?

# %%
# BEGIN SOLUTION

# P = O/(1+O)
# where P is the Probability and O is the odds, substitute O=0,37 into the formula

P = 0.37/(1+0.37)
print(P)


# END SOLUTION
# Out:
# 0.27007299270072993

# %% [markdown]
# Provide answer in the markdown cell
#
# To find the fraction of people who will actually default given the odds of 0.37, you can use the relationship between odds and probability. The formula to convert odds (\(O\)) to probability (\(P\)) is:
#
# \[ P = \frac{O}{1 + O} \]
#
# In your case, if the odds of defaulting on a credit card payment are 0.37, you can substitute this value into the formula:
#
# \[ P = \frac{0.37}{1 + 0.37} \]
#
# Calculate this expression to find the probability (\(P\)). The resulting probability represents the fraction of people who, on average, are expected to default given the odds of 0.37.
#
#
# Therefore, on average, approximately 27.01% of people with odds of 0.37 of defaulting on their credit card payment will actually default.

# %% [markdown]
# #### b) Suppose that an individual has a `16%` chance of defaulting on their credit card payment. What are the odds that they will default?

# %%
# BEGIN SOLUTION

'''O = p/(1-P)'''
O = 0.16/(1-0.16)
print(O)

# END SOLUTION
# Out:
# 0.1904761904761905

# %% [markdown]
# Answer:
# Provide answer in the markdown cell
#
# Certainly, let's calculate the odds of defaulting given a 16% chance. The formula to convert probability (\(P\)) to odds (\(O\)) is:
#
# \[ O = \frac{P}{1 - P} \]
#
# In your case, if the probability of defaulting on a credit card payment is 0.16, substitute this value into the formula:
#
# \[ O = \frac{0.16}{1 - 0.16} \]
#
# Now, let's calculate this expression:
#
# \[ O = \frac{0.16}{0.84} \]
#
# \[ O \approx 0.1905 \]
#
# Therefore, if an individual has a 16% chance of defaulting, the odds that they will default are approximately 0.1905.

# %% [markdown]
# #### Q3. Suppose that we take a data set, divide it into equally sized training and test sets, and then try out two different classification procedures. First, we use logistic regression and get an error rate of `20%` on the training data and `30%` on the test data. Next we use 1-nearest neighbors (i.e. `K=1`) and get an average error rate (averaged over both test and training data sets) of `18%`. Based on these results, which method should we prefer to use for classification of new observations? Why?

# %% [markdown]
# Answer:
# Provide answer in the markdown cell
#
# To determine which classification method is preferable, let's analyze the performance of logistic regression and 1-nearest neighbors (1-NN) based on the provided error rates.
#
# 1. **Logistic Regression:**
#    - Training Error Rate: 20%
#    - Test Error Rate: 30%
#
# 2. **1-Nearest Neighbors (K=1):**
#    - Average Error Rate (over both test and training data sets): 18%
#
# **Analysis:**
#
# - Logistic Regression:
#   - The test error rate is higher than the training error rate, indicating some degree of overfitting.
#   - The 30% test error rate might suggest that logistic regression is not generalizing well to new, unseen data.
#
# - 1-Nearest Neighbors (K=1):
#   - The average error rate is 18%, which is lower than the test error rate of logistic regression.
#   - 1-NN is a non-parametric method that can be flexible and adapt to the underlying structure of the data.
#
# **Preference:**
#
# Given the provided results, 1-Nearest Neighbors with \(K=1\) is performing better in terms of the average error rate. This suggests that 1-NN is capturing the underlying patterns in the data more effectively, at least on average over the training and test sets.
#
# **Caution:**
# - While 1-NN appears to be preferable based on the given results, it's essential to consider other factors such as computational efficiency, interpretability, and the potential impact of outliers in the dataset.
#
# In summary, based on the provided information, 1-Nearest Neighbors (K=1) seems to be the preferred method for classification of new observations due to its lower average error rate.

# %% [markdown]
# ## Applied

# %% [markdown]
# #### 4) This question should be answered using the `Weekly` data set, which is part of the `ISLR2` package. This data is similar in nature to the `Smarket` data examined in the book (Ch4, lab). First, load the dataset:
#
#
#  https://book.huihoo.com/introduction-to-statistical-learning/data.html
#
#  Link for getting rdataset into python:
#  https://www.statsmodels.org/dev/datasets/statsmodels.datasets.get_rdataset.html
#
#
#  By using the below command you can get the ISLR dataset
#  `sm.datasets.get_rdataset('Weekly', 'ISLR').data`

# %% [markdown]
# #### a) Produce some numerical and graphical summaries of the `Weekly` data. Can you identify any patterns? Hint: examine the __correlation__ between predictors.

# %% [markdown]
# **Importing Libraries:**

# %%
# !pip install statsmodels

# %%
#IMPORT LIBRARIES

import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Loading dataset:**

# %%
#READ Weekly DATASET USING THE CODE GIVEN IN QUESTION 4
# Load the "Weekly" dataset from the ISLR package
weekly_data = sm.datasets.get_rdataset('Weekly', 'ISLR').data

# %%
weekly_data
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today Direction
# 0     1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270      Down
# 1     1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576      Down
# 2     1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514        Up
# 3     1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712        Up
# 4     1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178        Up
# ...    ...    ...    ...    ...    ...    ...       ...    ...       ...
# 1084  2010 -0.861  0.043 -2.173  3.599  0.015  3.205160  2.969        Up
# 1085  2010  2.969 -0.861  0.043 -2.173  3.599  4.242568  1.281        Up
# 1086  2010  1.281  2.969 -0.861  0.043 -2.173  4.835082  0.283        Up
# 1087  2010  0.283  1.281  2.969 -0.861  0.043  4.454044  1.034        Up
# 1088  2010  1.034  0.283  1.281  2.969 -0.861  2.707105  0.069        Up
#
# [1089 rows x 9 columns]

# %%
#PERFORM PRE PROCESSING OF DATA IF REQUIRED ( OBSERVE THE DATASET AND ITS VALUES CAREFULLY)

# Check for missing values
missing_values = weekly_data.isnull().sum()
print(missing_values)
# Out:
# Year         0
# Lag1         0
# Lag2         0
# Lag3         0
# Lag4         0
# Lag5         0
# Volume       0
# Today        0
# Direction    0
# dtype: int64

# %%
# Display descriptive statistics
statistics = weekly_data.describe()
print(statistics)
# Out:
#               Year         Lag1         Lag2         Lag3         Lag4  \
# count  1089.000000  1089.000000  1089.000000  1089.000000  1089.000000
# mean   2000.048669     0.150585     0.151079     0.147205     0.145818
# std       6.033182     2.357013     2.357254     2.360502     2.360279
# min    1990.000000   -18.195000   -18.195000   -18.195000   -18.195000
# 25%    1995.000000    -1.154000    -1.154000    -1.158000    -1.158000
# 50%    2000.000000     0.241000     0.241000     0.241000     0.238000
# 75%    2005.000000     1.405000     1.409000     1.409000     1.409000
# max    2010.000000    12.026000    12.026000    12.026000    12.026000
#
#               Lag5       Volume        Today
# count  1089.000000  1089.000000  1089.000000
# mean      0.139893     1.574618     0.149899
# std       2.361285     1.686636     2.356927
# min     -18.195000     0.087465   -18.195000
# 25%      -1.166000     0.332022    -1.154000
# 50%       0.234000     1.002680     0.241000
# ...

# %%
sns.boxplot(data=weekly_data, orient="h")
# Out:
# <Axes: >

# %%
"""Please run this cell to replace outliers until outliers get replaced with median"""

# Define a function to replace outliers with the median
def replace_outliers_with_median(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    column = column.where((column >= lower_bound) & (column <= upper_bound), column.median())
    return column

# Apply the function to all numeric columns (excluding 'name' and 'mpg')
numeric_columns = weekly_data.select_dtypes(include=['number']).columns
weekly_data[numeric_columns] = weekly_data[numeric_columns].apply(replace_outliers_with_median)

# %%
sns.boxplot(data=weekly_data, orient="h")
# Out:
# <Axes: >

# %%
# BEGIN SOLUTION
# Encode categorical variable 'Direction'
weekly_data['Direction'] = weekly_data['Direction'].map({'Up': 1, 'Down': 0})


# Initialize the scaler
scaler = StandardScaler()

# Scale numerical features
weekly_data[['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today']] = scaler.fit_transform(weekly_data[['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume', 'Today']])

# Drop 'Year' column if not needed
# weekly_data = weekly_data.drop('Year', axis=1)


# END SOLUTION

# %%
# BEGIN SOLUTION

# Display summary statistics
summary_statistics = weekly_data.describe()
print(summary_statistics)

# Calculate correlation matrix
correlation_matrix = weekly_data.corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()


# END SOLUTION
# Out:
#                Lag1          Lag2          Lag3          Lag4          Lag5  \
# count  1.089000e+03  1.089000e+03  1.089000e+03  1.089000e+03  1.089000e+03
# mean   3.262363e-18 -6.524727e-18  2.283654e-17  9.787090e-18  2.283654e-17
# std    1.000459e+00  1.000459e+00  1.000459e+00  1.000459e+00  1.000459e+00
# min   -2.588187e+00 -2.587979e+00 -2.578235e+00 -2.577694e+00 -2.571416e+00
# 25%   -6.710010e-01 -6.711678e-01 -6.687192e-01 -6.678728e-01 -6.646915e-01
# 50%    1.573424e-02  1.543309e-02  1.771964e-02  1.687103e-02  1.817078e-02
# 75%    6.216061e-01  6.223931e-01  6.229410e-01  6.227911e-01  6.228887e-01
# max    2.552068e+00  2.551271e+00  2.546293e+00  2.547655e+00  2.548849e+00
#
#              Volume         Today    Direction
# count  1.089000e+03  1.089000e+03  1089.000000
# mean   4.175825e-16 -1.304945e-17     0.555556
# std    1.000459e+00  1.000459e+00     0.497132
# min   -1.544855e+00 -2.587921e+00     0.000000
# ...

# %%
# BEGIN SOLUTION

correlation_matrix

# END SOLUTION
# Out:
#                Lag1      Lag2      Lag3      Lag4      Lag5    Volume  \
# Lag1       1.000000 -0.102842  0.054943 -0.028569 -0.020203 -0.014606
# Lag2      -0.102842  1.000000 -0.104423  0.054451 -0.030967 -0.030165
# Lag3       0.054943 -0.104423  1.000000 -0.103576  0.059265 -0.021085
# Lag4      -0.028569  0.054451 -0.103576  1.000000 -0.103942 -0.016587
# Lag5      -0.020203 -0.030967  0.059265 -0.103942  1.000000 -0.013860
# Volume    -0.014606 -0.030165 -0.021085 -0.016587 -0.013860  1.000000
# Today     -0.103181  0.055935 -0.028522 -0.019602 -0.063474 -0.024013
# Direction -0.066139  0.059412 -0.000809  0.002447 -0.034815 -0.035864
#
#               Today  Direction
# Lag1      -0.103181  -0.066139
# Lag2       0.055935   0.059412
# Lag3      -0.028522  -0.000809
# Lag4      -0.019602   0.002447
# Lag5      -0.063474  -0.034815
# Volume    -0.024013  -0.035864
# Today      1.000000   0.774273
# Direction  0.774273   1.000000

# %% [markdown]
# Certainly! Let's examine the patterns in the correlation between predictors in the "Weekly" dataset:
#
# 1. **Weak Correlations Between Predictors:**
#    - The correlations between "Lag1" through "Lag5" are generally weak, ranging from -0.103 to 0.059. This suggests that there is not a strong linear relationship between the returns of consecutive weeks.
#
# 2. **Limited Multicollinearity:**
#    - The lack of strong correlations between the lagged returns indicates that there is limited multicollinearity among these predictors. This is beneficial when building predictive models, as it suggests that each lagged return provides unique information.
#
# 3. **Correlation with Today's Return:**
#    - The correlations between "Today" and the lagged returns are modest, with the highest correlation observed with "Lag2" at 0.056. This indicates that there is some relationship between today's return and the returns of the previous two weeks.
#
# 4. **Correlation with Volume:**
#    - The "Volume" variable has weak correlations with the lagged returns, ranging from -0.021 to -0.031. This suggests that the trading volume is not strongly correlated with the returns of the previous weeks.
#
# In summary, the patterns in the correlation matrix suggest that there is no significant multicollinearity among the lagged returns, and today's return shows modest correlations with the lagged returns. These patterns can guide the feature selection process when building predictive models.

# %% [markdown]
# You can refer to the `seaborn` library documentation to attempt this problem: https://seaborn.pydata.org/

# %% [markdown]
# #### b) Use the full data set to perform a logistic regression with Direction as the response and the five `lag` variables plus `Volume` as predictors. Use the summary function to print the results. Do any of the predictors appear to be statistically significant? If so, which ones? Use the statsmodels to construct the classifier.
#
# Link: https://www.statsmodels.org/

# %%
#BEGIN SOLUTION

import statsmodels.api as sm

# Define predictors (features)
predictors = ['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume']

# Add a constant term to the predictors
X = sm.add_constant(weekly_data[predictors])

# Define the response variable
y = weekly_data['Direction']

# Fit logistic regression model
logit_model = sm.Logit(y, X)
result = logit_model.fit()

# Display the summary
print(result.summary())


# END SOLUTION
# Out:
# Optimization terminated successfully.
#          Current function value: 0.682067
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:              Direction   No. Observations:                 1089
# Model:                          Logit   Df Residuals:                     1082
# Method:                           MLE   Df Model:                            6
# Date:                Sat, 18 Nov 2023   Pseudo R-squ.:                0.007125
# Time:                        12:56:13   Log-Likelihood:                -742.77
# converged:                       True   LL-Null:                       -748.10
# Covariance Type:            nonrobust   LLR p-value:                   0.09946
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2253      0.061      3.675      0.000       0.105       0.345
# ...

# %% [markdown]
# Yes, based on the p-values from the logistic regression results, "Lag1" appears to be statistically significant at the 0.05 significance level, with a p-value of 0.040. This suggests that "Lag1" is associated with the direction of the market.
#
# The other predictors, including "Lag2," "Lag3," "Lag4," "Lag5," and "Volume," do not appear to be statistically significant at the conventional 0.05 significance level. Their p-values are greater than 0.05.
#
# To construct the classifier using the significant predictors, you can create a logistic regression model using only the significant variables. Let's construct the classifier using only "Lag1" as the predictor:

# %%
# BEGIN SOLUTION

# Define the significant predictor
significant_predictors = ['Lag1']

# Add a constant term to the predictors
X_significant = sm.add_constant(weekly_data[significant_predictors])

# Fit logistic regression model with the significant predictor
logit_model_significant = sm.Logit(y, X_significant)
result_significant = logit_model_significant.fit()

# Display the summary
print(result_significant.summary())


# END SOLUTION
# Out:
# Optimization terminated successfully.
#          Current function value: 0.684770
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:              Direction   No. Observations:                 1089
# Model:                          Logit   Df Residuals:                     1087
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 18 Nov 2023   Pseudo R-squ.:                0.003191
# Time:                        12:59:45   Log-Likelihood:                -745.71
# converged:                       True   LL-Null:                       -748.10
# Covariance Type:            nonrobust   LLR p-value:                   0.02889
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2241      0.061      3.667      0.000       0.104       0.344
# ...

# %% [markdown]
# #### C) Compute the confusion matrix and overall fraction of correct predictions. Explain what the confusion matrix is telling you about the types of mistakes made by logistic regression.

# %%
# BEGIN SOLUTION

from sklearn.metrics import confusion_matrix, accuracy_score

# Predict the direction using the logistic regression model
y_pred = result_significant.predict(X_significant) > 0.5
y_pred = y_pred.astype(int)

# Create the confusion matrix
conf_matrix = confusion_matrix(y, y_pred)

# Compute the overall fraction of correct predictions
accuracy = accuracy_score(y, y_pred)

# Display the confusion matrix and accuracy
print("Confusion Matrix:")
print(conf_matrix)
print("\nOverall Fraction of Correct Predictions:", accuracy)


# END SOLUTION
# Out:
# Confusion Matrix:
# [[ 30 454]
#  [ 32 573]]
#
# Overall Fraction of Correct Predictions: 0.5537190082644629

# %% [markdown]
# ```
# Confusion Matrix:
# [[ 30 454]
#  [ 32 573]]
# ```
#
# - **True Positive (TP):** 30
# - **True Negative (TN):** 573
# - **False Positive (FP):** 454
# - **False Negative (FN):** 32
#
# **Overall Fraction of Correct Predictions (Accuracy):** 55.37%
#
# Now, let's interpret the confusion matrix:
#
# 1. **True Positive (TP):**
#    - The model correctly predicted "Up" (the positive class) 30 times.
#
# 2. **True Negative (TN):**
#    - The model correctly predicted "Down" (the negative class) 573 times.
#
# 3. **False Positive (FP):**
#    - The model incorrectly predicted "Up" 454 times when the actual direction was "Down." These are Type I errors or false positives.
#
# 4. **False Negative (FN):**
#    - The model incorrectly predicted "Down" 32 times when the actual direction was "Up." These are Type II errors or false negatives.
#
# **Interpretation:**
# - The overall fraction of correct predictions (accuracy) is 55.37%, indicating that the model correctly predicted the market direction for approximately 55.37% of the observations.
#
# - The confusion matrix highlights the types of mistakes made by the logistic regression model. In this case, there is a higher number of false positives (454) compared to false negatives (32). This suggests that the model tends to be more conservative in predicting "Up" (positive class), resulting in more instances where it incorrectly predicts "Up" when the actual direction is "Down."
#
# It's essential to consider the specific context and implications of false positives and false negatives based on the goals of your analysis or application.

# %% [markdown]
# **Observations:**

# %% [markdown]
# #### d) Now fit the logistic regression model using a training data period from __1990 to 2008__, with `Lag2` as the only predictor. Compute the confusion matrix and the overall fraction of correct predictions for the held out data (that is, the data from __2009 and 2010__).

# %%
# BEGIN SOLUTION

import statsmodels.api as sm
from sklearn.metrics import confusion_matrix, accuracy_score

# Define the training data period (1990 to 2008)
training_data = weekly_data[weekly_data['Year'] <= 2008]

# Define the held-out data period (2009 and 2010)
held_out_data = weekly_data[weekly_data['Year'] >= 2009]

# Define the predictor and response variables for training
X_train = sm.add_constant(training_data[['Lag2']])
y_train = training_data['Direction']

# Define the predictor and response variables for held-out data
X_held_out = sm.add_constant(held_out_data[['Lag2']])
y_held_out = held_out_data['Direction']


# END SOLUTION

# %%
# BEGIN SOLUTION

# Fit logistic regression model on training data
logit_model_train = sm.Logit(y_train, X_train)
result_train = logit_model_train.fit()

# Predictions on held-out data
y_pred_held_out = result_train.predict(X_held_out) > 0.5
y_pred_held_out = y_pred_held_out.astype(int)

# Create the confusion matrix for held-out data
conf_matrix_held_out = confusion_matrix(y_held_out, y_pred_held_out)

# Compute the overall fraction of correct predictions for held-out data
accuracy_held_out = accuracy_score(y_held_out, y_pred_held_out)


# END SOLUTION
# Out:
# Optimization terminated successfully.
#          Current function value: 0.685527
#          Iterations 4

# %%
#BEGIN SOLUTION

# Display the confusion matrix and accuracy for held-out data
print("Confusion Matrix (Held-Out Data):")
print(conf_matrix_held_out)
print("\nOverall Fraction of Correct Predictions (Held-Out Data):", accuracy_held_out)

#END SOLUTION
# Out:
# Confusion Matrix (Held-Out Data):
# [[ 3 40]
#  [ 4 57]]
#
# Overall Fraction of Correct Predictions (Held-Out Data): 0.5769230769230769

# %% [markdown]
# The logistic regression model trained on the data from 1990 to 2008, with "Lag2" as the only predictor, and evaluated on the held-out data from 2009 and 2010, resulted in the following performance metrics:
#
# **Confusion Matrix (Held-Out Data):**
# ```plaintext
# [[ 3 40]
#  [ 4 57]]
# ```
#
# - **True Positive (TP):** 3
# - **True Negative (TN):** 57
# - **False Positive (FP):** 40
# - **False Negative (FN):** 4
#
# **Overall Fraction of Correct Predictions (Accuracy):** 57.69%
#
# **Interpretation:**
# - The overall fraction of correct predictions (accuracy) on the held-out data is 57.69%.
# - The confusion matrix provides a breakdown of the model's predictions, indicating the number of true positives, true negatives, false positives, and false negatives.
#
# **Implications:**
# - The model correctly predicted the direction (either "Up" or "Down") for approximately 57.69% of the observations in the held-out data.
# - False positives (40) are instances where the model predicted "Up" when the actual direction was "Down."
# - False negatives (4) are instances where the model predicted "Down" when the actual direction was "Up."

# %% [markdown]
# #### e)Repeat (d) using LDA.

# %%
# BEGIN SOLUTION

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score

# Define the training data period (1990 to 2008)
training_data_lda = weekly_data[weekly_data['Year'] <= 2008]

# Define the held-out data period (2009 and 2010)
held_out_data_lda = weekly_data[weekly_data['Year'] >= 2009]

# Define the predictor and response variables for training (using Lag2)
X_train_lda = training_data_lda[['Lag2']]
y_train_lda = training_data_lda['Direction']

# Define the predictor and response variables for held-out data (using Lag2)
X_held_out_lda = held_out_data_lda[['Lag2']]
y_held_out_lda = held_out_data_lda['Direction']


# END SOLUTION

# %%
# BEGIN SOLUTION

# Fit LDA model on training data
lda_model = LinearDiscriminantAnalysis()
lda_model.fit(X_train_lda, y_train_lda)

# Predictions on held-out data
y_pred_held_out_lda = lda_model.predict(X_held_out_lda)

# Create the confusion matrix for held-out data using LDA
conf_matrix_held_out_lda = confusion_matrix(y_held_out_lda, y_pred_held_out_lda)

# Compute the overall fraction of correct predictions for held-out data using LDA
accuracy_held_out_lda = accuracy_score(y_held_out_lda, y_pred_held_out_lda)


# END SOLUTION

# %%
# BEGIN SOLUTION

# Display the confusion matrix and accuracy for held-out data using LDA
print("Confusion Matrix (Held-Out Data) - LDA:")
print(conf_matrix_held_out_lda)
print("\nOverall Fraction of Correct Predictions (Held-Out Data) - LDA:", accuracy_held_out_lda)


# END SOLUTION
# Out:
# Confusion Matrix (Held-Out Data) - LDA:
# [[ 3 40]
#  [ 4 57]]
#
# Overall Fraction of Correct Predictions (Held-Out Data) - LDA: 0.5769230769230769

# %% [markdown]
# #### f) Repeat (d) using QDA.

# %%
# BEGIN SOLUTION

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score

# Define the training data period (1990 to 2008)
training_data_qda = weekly_data[weekly_data['Year'] <= 2008]

# Define the held-out data period (2009 and 2010)
held_out_data_qda = weekly_data[weekly_data['Year'] >= 2009]

# Define the predictor and response variables for training (using Lag2)
X_train_qda = training_data_qda[['Lag2']]
y_train_qda = training_data_qda['Direction']

# Define the predictor and response variables for held-out data (using Lag2)
X_held_out_qda = held_out_data_qda[['Lag2']]
y_held_out_qda = held_out_data_qda['Direction']

# END SOLUTION

# %%
# BEGIN SOLUTION

# Fit QDA model on training data
qda_model = QuadraticDiscriminantAnalysis()
qda_model.fit(X_train_qda, y_train_qda)

# Predictions on held-out data
y_pred_held_out_qda = qda_model.predict(X_held_out_qda)

# Create the confusion matrix for held-out data using QDA
conf_matrix_held_out_qda = confusion_matrix(y_held_out_qda, y_pred_held_out_qda)

# Compute the overall fraction of correct predictions for held-out data using QDA
accuracy_held_out_qda = accuracy_score(y_held_out_qda, y_pred_held_out_qda)

# END SOLUTION

# %%
# BEGIN SOLUTION

# Display the confusion matrix and accuracy for held-out data using QDA
print("Confusion Matrix (Held-Out Data) - QDA:")
print(conf_matrix_held_out_qda)
print("\nOverall Fraction of Correct Predictions (Held-Out Data) - QDA:", accuracy_held_out_qda)


# END SOLUTION
# Out:
# Confusion Matrix (Held-Out Data) - QDA:
# [[ 3 40]
#  [ 3 58]]
#
# Overall Fraction of Correct Predictions (Held-Out Data) - QDA: 0.5865384615384616

# %% [markdown]
# #### g) Repeat (d) using KNN with K=1

# %%
# BEGIN SOLUTION

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Define the training data period (1990 to 2008)
training_data_knn = weekly_data[weekly_data['Year'] <= 2008]

# Define the held-out data period (2009 and 2010)
held_out_data_knn = weekly_data[weekly_data['Year'] >= 2009]

# Define the predictor and response variables for training (using Lag2)
X_train_knn = training_data_knn[['Lag2']]
y_train_knn = training_data_knn['Direction']

# Define the predictor and response variables for held-out data (using Lag2)
X_held_out_knn = held_out_data_knn[['Lag2']]
y_held_out_knn = held_out_data_knn['Direction']


# END SOLUTION

# %%
# BEGIN SOLUTION

# Create a KNN classifier with K=1
knn_model = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=1))

# Fit KNN model on training data
knn_model.fit(X_train_knn, y_train_knn)

# Predictions on held-out data
y_pred_held_out_knn = knn_model.predict(X_held_out_knn)

# Create the confusion matrix for held-out data using KNN
conf_matrix_held_out_knn = confusion_matrix(y_held_out_knn, y_pred_held_out_knn)

# Compute the overall fraction of correct predictions for held-out data using KNN
accuracy_held_out_knn = accuracy_score(y_held_out_knn, y_pred_held_out_knn)

# END SOLUTION

# %%
# BEGIN SOLUTION

# Display the confusion matrix and accuracy for held-out data using KNN
print("Confusion Matrix (Held-Out Data) - KNN (K=1):")
print(conf_matrix_held_out_knn)
print("\nOverall Fraction of Correct Predictions (Held-Out Data) - KNN (K=1):", accuracy_held_out_knn)


# END SOLUTION
# Out:
# Confusion Matrix (Held-Out Data) - KNN (K=1):
# [[18 25]
#  [28 33]]
#
# Overall Fraction of Correct Predictions (Held-Out Data) - KNN (K=1): 0.49038461538461536

# %% [markdown]
# #### h) Which of these methods appears to provide the best results on this data?

# %% [markdown]
# Answer: Provide your answer in this Markdown cell
#
# To determine which method provides the best results, we can compare the overall fraction of correct predictions (accuracy) for each method on the held-out data.
#
# Let's summarize the results:
#
# - Logistic Regression: 57.69%
# - Linear Discriminant Analysis (LDA): 57.69%
# - Quadratic Discriminant Analysis (QDA): 58.65%
# - k-Nearest Neighbors (KNN) with \(K=1\): 49.04%
#
# The method with the highest accuracy on the held-out data appears to be Quadratic Discriminant Analysis (QDA) with an accuracy of 58.65%.
#
# It's important to note that the choice of the "best" method can depend on the specific goals of the analysis, the characteristics of the data, and other considerations. In this case, based on the provided accuracy results, QDA performs slightly better than the other methods.

# %% [markdown]
# ### 5) Develop a model to predict whether a given car gets high or low gas mileage based on the `Auto` data set. Load the dataset:

# %%
# BEGIN SOLUTION
#Load dataset

#IMPORT LIBRARIES
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import statsmodels.api as sm

import matplotlib.pyplot as plt

#READ AUTO.CSV DATASET
df = pd.read_csv('Auto.csv')

# END SOLUTION

# %%
# BEGIN SOLUTION

# Check for missing data
missing_data = df.isnull().sum()
print(missing_data)

# END SOLUTION
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
# BEGIN SOLUTION

# Convert 'horsepower' to numeric, handling potential non-numeric values
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# END SOLUTION

# %%
# Check for missing data
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
df['horsepower'].median()
# Out:
# 93.5

# %%
df['horsepower'].fillna(df['horsepower'].median(), inplace=True)

# %%
# Check for missing data
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
sns.boxplot(data=df, orient="h")
# Out:
# <Axes: >

# %%
"""Please run this cell to replace outliers until outliers get replaced with median"""

# Define a function to replace outliers with the median
def replace_outliers_with_median(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    column = column.where((column >= lower_bound) & (column <= upper_bound), column.median())
    return column

# Apply the function to all numeric columns (excluding 'name' and 'mpg')
numeric_columns = df.select_dtypes(include=['number']).columns
df[numeric_columns] = df[numeric_columns].apply(replace_outliers_with_median)

# %%
sns.boxplot(data=df, orient="h")
# Out:
# <Axes: >

# %% [markdown]
# a) Create a binary variable, `mpg01`, that contains a `1` if `mpg` contains a value above its median, and a `0` if `mpg` contains a value below its median.Note : you may find it helpful to use the `pd.DataFrame()` function to create a single data set containing both `mpg01` and the other `Auto` variables.
#
# Link to median():
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.median.html

# %%
# BEGIN SOLUTION

# Create a binary variable mpg01
median_mpg = df['mpg'].median()
df['mpg01'] = (df['mpg'] > median_mpg).astype(int)

# END SOLUTION

# %%
median_mpg
# Out:
# 23.0

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        93.5    3504          12.0    70
# 1    15.0          8         350.0        93.5    3693          11.5    70
# 2    18.0          8         318.0        93.5    3436          11.0    70
# 3    16.0          8         304.0        93.5    3433          12.0    70
# 4    17.0          8         302.0        93.5    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        93.5    2130          15.5    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name  mpg01
# ...

# %% [markdown]
# #### b) Explore the data graphically in order to investigate the association between `mpg01` and the other features. Which of the other features seem most likely to be useful in predicting `mpg01`? Scatterplots and boxplots may be useful tools to answer this question Describe your findings
#
# Link to Scatter plot: https://seaborn.pydata.org/generated/seaborn.scatterplot.html
#
# Link to Violin plot: https://seaborn.pydata.org/generated/seaborn.violinplot.html
#
# Link to Box plot: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# BEGIN SOLUTION

import seaborn as sns
import matplotlib.pyplot as plt

# Scatterplots
pair_plot = sns.pairplot(df, hue='mpg01', vars=['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin'], markers=['o', 's'], palette='husl')
plt.show()

# END SOLUTION

# %%
# Extract statistical information
pair_plot.data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        93.5    3504          12.0    70
# 1    15.0          8         350.0        93.5    3693          11.5    70
# 2    18.0          8         318.0        93.5    3436          11.0    70
# 3    16.0          8         304.0        93.5    3433          12.0    70
# 4    17.0          8         302.0        93.5    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        93.5    2130          15.5    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name  mpg01
# ...

# %%
# BEGIN SOLUTION

# Boxplots
plt.figure(figsize=(15, 8))
sns.boxplot(x='mpg01', y='cylinders', data=df)
plt.show()


# END SOLUTION

# %%
# BEGIN SOLUTION

plt.figure(figsize=(15, 8))
sns.boxplot(x='mpg01', y='displacement', data=df)
plt.show()

# END SOLUTION

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='mpg01', y='horsepower', data=df)
plt.show()

# %% [markdown]
# 1. **Diagonal (Histograms):**
#    - Check the histograms for each variable (cylinders, displacement, horsepower, weight, acceleration, year, origin) split by the `mpg01` classes.
#    - Look for differences in the distributions. If there are distinct patterns for high or low `mpg` values, it suggests that the variable might be informative for predicting `mpg01`.
#
# 2. **Above and Below Diagonal (Scatter Plots):**
#    - Examine the scatter plots above and below the diagonal. Each point represents an observation, colored by `mpg01`.
#    - Look for patterns or separations between the two classes. If points with different `mpg01` values form distinct clusters or exhibit separation, it indicates potential predictive power.
#
# 3. **Correlation and Strength of Association:**
#    - Check the correlation between variables. Positive or negative correlations between a variable and `mpg01` may suggest the predictive power of that variable.
#    - Stronger associations between variables and `mpg01` may indicate variables that are more likely to be useful in predicting whether a car has high or low gas mileage.
#
# 4. **Boxplots (Optional):**
#    - You can also refer to the boxplots for each variable to visualize the distribution of values across `mpg01` classes. Look for differences in medians and spreads.

# %% [markdown]
# #### C) Split the data into a training set and a test set (70%, 30%). Use `random.seed(4)` to make the training data reproducible.
#
# Link to linear model: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# BEGIN SOLUTION

from sklearn.model_selection import train_test_split

# Set the seed for reproducibility
import random
random.seed(4)

# Define features (X) and target variable (y)
X = df[['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']]
y = df['mpg01']

# Split the data into a training set (70%) and a test set (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)

# Display the shapes of the resulting sets
print("Training set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)


# END SOLUTION
# Out:
# Training set shape: (277, 7) (277,)
# Test set shape: (120, 7) (120,)

# %% [markdown]
# #### d) Perform LDA on the training data in order to predict `mpg01` using the variables that seemed most associated with `mpg01` in (b). What is the test error of the model obtained?

# %%
# BEGIN SOLUTION

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score

# END SOLUTION

# %%
# BEGIN SOLUTION

# Create an LDA model
lda = LinearDiscriminantAnalysis()

# END SOLUTION

# %%
# BEGIN SOLUTION

# Train the model on the training data
lda.fit(X_train, y_train)

# END SOLUTION
# Out:
# LinearDiscriminantAnalysis()

# %%
# BEGIN SOLUTION

# Make predictions on the test set
y_pred = lda.predict(X_test)

# END SOLUTION

# %%
# BEGIN SOLUTION

# Calculate the accuracy (test error) of the model
accuracy = accuracy_score(y_test, y_pred)

# END SOLUTION

# %%
# BEGIN SOLUTION

# Display the test error
print("Test Error (Accuracy): {:.2%}".format(1 - accuracy))

# END SOLUTION
# Out:
# Test Error (Accuracy): 5.83%

# %% [markdown]
# #### e) Perform QDA on the training data in order to predict `mpg01` using the variables that seemed most associated with `mpg01` in (b). What is the test error of the model obtained?

# %%
# BEGIN SOLUTION

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import accuracy_score

# END SOLUTION

# %%
 # BEGIN SOLUTION

# 'selected_features' contains the features identified in part (b)
selected_features = ['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']

# END SOLUTION

# %% [markdown]
# To perform Quadratic Discriminant Analysis (QDA) on the training data and predict mpg01 using the variables identified in part (b), you can use the QuadraticDiscriminantAnalysis class from the sklearn.discriminant_analysis module.

# %%
# BEGIN SOLUTION

# Create a QDA model
qda = QuadraticDiscriminantAnalysis()

# END SOLUTION

# %%
# BEGIN SOLUTION

# Train the model on the training data with selected features
qda.fit(X_train[selected_features], y_train)

# Make predictions on the test set with selected features
y_pred_qda = qda.predict(X_test[selected_features])

# Calculate the accuracy (test error) of the QDA model
accuracy_qda = accuracy_score(y_test, y_pred_qda)

# END SOLUTION

# %%
# Display the test error for QDA
print("QDA Test Error (Accuracy): {:.2%}".format(1 - accuracy_qda))
# Out:
# QDA Test Error (Accuracy): 10.00%

# %% [markdown]
# The QDA test error (accuracy) of 10.00% suggests that the model is accurate in predicting the `mpg01` class for the test data. An accuracy of 90.00% indicates that the model correctly predicted the `mpg01` class for 90.00% of the observations in the test set.

# %% [markdown]
# #### f) Perform logistic regression on the training data in order to predict `mpg01` using the variables that seemed most associated with `mpg01` in (b). What is the test error of the model obtained?
#
# Link to linear model: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
# BEGIN SOLUTION

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# END SOLUTION

# %% [markdown]
# To perform logistic regression on the training data and predict mpg01 using the variables identified in part (b), you can use the LogisticRegression class from the sklearn.linear_model module.

# %%
# BEGIN SOLUTION

# Assuming 'selected_features' contains the features identified in part (b)
selected_features = ['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']

# END SOLUTION

# %%
# BEGIN SOLUTION

# Create a logistic regression model
logreg = LogisticRegression()

# Train the model on the training data with selected features
logreg.fit(X_train[selected_features], y_train)

# Make predictions on the test set with selected features
y_pred_logreg = logreg.predict(X_test[selected_features])

# Calculate the accuracy (test error) of the logistic regression model
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)

# END SOLUTION

# %%
# Display the test error for logistic regression
print("Logistic Regression Test Error (Accuracy): {:.2%}".format(1 - accuracy_logreg))
# Out:
# Logistic Regression Test Error (Accuracy): 7.50%

# %% [markdown]
# The Logistic Regression test error (accuracy) of 7.50% indicates that the model is accurate in predicting the mpg01 class for the test data. An accuracy of 92.50% suggests that the model correctly predicted the mpg01 class for 92.50% of the observations in the test set.
